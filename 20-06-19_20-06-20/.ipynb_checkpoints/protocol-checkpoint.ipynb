# %% [markdown]
# # pre-night (20-06-18)

# %% [markdown]
# **Goals:**
# None today, just check the sleep data.

# %% [markdown]
# # post-night  (20-06-19)

# %% [markdown]
# ## problems

# %% [markdown]
# * no motivation to add dream report today

# %% [markdown]
# ## data analyses

# %%
# %matplotlib notebook

# import the python functions
import sys
sys.path.insert(1, '../python_functions3')
from python_functions3 import *

# %%
# manually add the time points of dream report onsets
report_times = [
    #[False,2,39,56],
]

# read in data
df = pd.read_excel('raw_data.xlsx')
# Out:
#      Schlafbeginn       Schlafbeginn.1  Schlaf beenden     Schlaf beenden.1  \
# 0   1592601360514  19/06/2020 23:16:00   1592608740514  20/06/2020 01:19:00
# 1   1592608740514  20/06/2020 01:19:00   1592609460514  20/06/2020 01:31:00
# 2   1592609460514  20/06/2020 01:31:00   1592611800514  20/06/2020 02:10:00
# 3   1592611800514  20/06/2020 02:10:00   1592612580514  20/06/2020 02:23:00
# 4   1592612580514  20/06/2020 02:23:00   1592616720514  20/06/2020 03:32:00
# 5   1592616720514  20/06/2020 03:32:00   1592617680514  20/06/2020 03:48:00
# 6   1592617680514  20/06/2020 03:48:00   1592619360514  20/06/2020 04:16:00
# 7   1592619360514  20/06/2020 04:16:00   1592620200514  20/06/2020 04:30:00
# 8   1592620200514  20/06/2020 04:30:00   1592621220514  20/06/2020 04:47:00
# 9   1592621220514  20/06/2020 04:47:00   1592621940514  20/06/2020 04:59:00
# 10  1592621940514  20/06/2020 04:59:00   1592624100514  20/06/2020 05:35:00
# 11  1592624100514  20/06/2020 05:35:00   1592627040514  20/06/2020 06:24:00
# 12  1592627040514  20/06/2020 06:24:00   1592637840514  20/06/2020 09:24:00
# 13  1592637840514  20/06/2020 09:24:00   1592638680514  20/06/2020 09:38:00
# 14  1592638680514  20/06/2020 09:38:00   1592639520000  20/06/2020 09:52:00
#
#           Schlaftyp  Minuten geschlafen
# 0   Leichter Schlaf                 123
# 1        Tiefschlaf                  12
# 2   Leichter Schlaf                  39
# 3        Tiefschlaf                  13
# 4   Leichter Schlaf                  69
# 5        Tiefschlaf                  16
# 6   Leichter Schlaf                  28
# 7        Tiefschlaf                  14
# 8   Leichter Schlaf                  17
# 9        Tiefschlaf                  12
# 10  Leichter Schlaf                  36
# 11       Tiefschlaf                  49
# 12  Leichter Schlaf                 180
# 13       Tiefschlaf                  14
# 14  Leichter Schlaf                  13

# %%
[state_onsets, depths_succ] = read_raw_data(df)

# manually add the time i went to bed / lights off (from note app and phone)
# make sure that if this is later than smartwatch-detected onset, get the later onset
lights_off_time = datetime.datetime.strptime("20/06/2020 00:27:0", '%d/%m/%Y %H:%M:%S')
if lights_off_time < state_onsets[0]:
    state_onsets = [lights_off_time] + state_onsets
elif lights_off_time > state_onsets[0]:
    state_onsets = [lights_off_time] + state_onsets
    state_onsets[1] = lights_off_time
depths_succ = [0] + depths_succ

# get the time points of dream report onsets
dts_reports = []
for rt in report_times:
    dt_object = get_datetime(*rt)
    date = matplotlib.dates.date2num(dt_object)
    dts_reports.append(date)

# %%
# put together hypnogram plot
ax = get_ax(state_onsets, depths_succ)
for dtr in dts_reports:
    plt.axvline(x=dtr, c="red", linewidth=0.75)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## what i've learned

# %% [markdown]
# ## try sometime next:
